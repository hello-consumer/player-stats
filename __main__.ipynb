# %%
import json
import pandas as pd

with open('players.json','r', encoding='utf-8') as f:
    data=json.load(f)

rows=[]
players = data.get('players', {}).get('result', [])
for p in players:
    if p.get('status') == "INJ":
        continue
    hist = p.get('fantasyPointsHistory', [])
    if len(hist) >= 2:
        avg = sum(hist[:2]) / 2
        salary = p.get('salary', 0)
        diff = avg - salary
        if diff > 0:
            rows.append({
                "name": f"{p.get('firstName','')} {p.get('lastName','')}",
                "avg_last2": avg,
                "salary": salary,
                "diff": diff
            })

df = pd.DataFrame(rows).sort_values('diff', ascending=False).head(20)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
display(df)
# Out:
#                    name  avg_last2  salary   diff
# 5        Oscar Tshiebwe      36.60      10  26.60
# 21         Jaylen Brown      66.10      41  25.10
# 28            Josh Hart      51.30      28  23.30
# 73    Julian Champagnie      41.10      19  22.10
# 97           Saddiq Bey      41.95      21  20.95
# 80        Keegan Murray      48.30      28  20.30
# 9         Aaron Holiday      25.15      10  15.15
# 56  Robert Williams III      30.75      16  14.75
# 75    Russell Westbrook      44.25      30  14.25
# 2         Kyle Anderson      27.15      13  14.15
# 44         Jared McCain      31.00      17  14.00
# 86   Vince Williams Jr.      33.00      20  13.00
# 13        Reed Sheppard      39.50      27  12.50
# 70          Luke Kornet      28.00      16  12.00
# 72        Devin Vassell      38.90      27  11.90
# 3        Keyonte George      47.85      36  11.85
# 98        Jose Alvarado      27.80      16  11.80
# 39          A.J. Lawson      21.50      10  11.50
# 69         De'Aaron Fox      51.20      40  11.20
# 4      Brice Sensabaugh      26.15      15  11.15
